# %%
import pandas as pd
import numpy as np
import requests
import tweepy
import json

# %% [markdown]
# ## Load the `twitter archive enhanced csv` file into the pandas dataframe

# %%
Dog_twits_df = pd.read_csv('Datasets/twitter-archive-enhanced.csv')

# %%
Dog_twits_df.sample(5)
# Out:
#                 tweet_id  in_reply_to_status_id  in_reply_to_user_id  \
# 685   788150585577050112                    NaN                  NaN
# 939   753039830821511168                    NaN                  NaN
# 653   792050063153438720                    NaN                  NaN
# 1095  736392552031657984                    NaN                  NaN
# 1788  677557565589463040                    NaN                  NaN
#
#                       timestamp  \
# 685   2016-10-17 22:51:57 +0000
# 939   2016-07-13 01:34:21 +0000
# 653   2016-10-28 17:07:05 +0000
# 1095  2016-05-28 03:04:00 +0000
# 1788  2015-12-17 18:34:46 +0000
#
#                                                  source  \
# 685   <a href="http://twitter.com/download/iphone" r...
# 939   <a href="http://vine.co" rel="nofollow">Vine -...
# 653   <a href="http://twitter.com/download/iphone" r...
# 1095  <a href="http://vine.co" rel="nofollow">Vine -...
# 1788  <a href="http://twitter.com/download/iphone" r...
#
# ...

# %% [markdown]
# ## Download the tweet
